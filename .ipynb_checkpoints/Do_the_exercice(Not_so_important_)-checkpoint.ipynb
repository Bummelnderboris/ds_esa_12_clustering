# %%
# This notebooks solves the given exercice but is ment to be as the second option
# But at the moment i am trying to finish the k means algorithm from scratch and hope to be done before the review
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans

df= pd.read_csv('https://drive.google.com/uc?id=1sTO90PQRtbK80XdzMJ2KttRRtt9M7xuq')
ds = df.to_numpy()

# %%
dist = []
c = range(1,15)
for k in c:
  kmeanModel = KMeans(n_clusters=k)
  kmeanModel.fit(df)
  dist.append(kmeanModel.inertia_)

plt.plot(c, dist, 'bx-')

# %%
# It seems like the optimal k is 5 or 6. Let's go with 5

model = KMeans(n_clusters=5)
model.fit(df)
labels = model.predict(df)

#df['pred_class'] = labels
df[0:10]
# Out:
#          V1        V2        V3
# 0 -5.340236  4.747246  3.823326
# 1 -9.587065 -3.434466  9.701839
# 2 -8.385012 -3.902794  8.514620
# 3  5.708226  2.658575  5.404482
# 4 -7.431665 -4.390251  9.003216
# 5  5.028509  9.047695 -8.548437
# 6  6.372196  4.459940  4.369358
# 7 -8.355252 -3.516956  7.162714
# 8 -3.405266  2.281427 -7.631172
# 9  5.621561  3.431056  4.666574

# %%
#B: Plot the clusteres
center = model.cluster_centers_

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(ds[:, 0], ds[:, 1], ds[:, 2], c=labels)
ax.scatter(center[:,0], center[:,1], center[:,2])
